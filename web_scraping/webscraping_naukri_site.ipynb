eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzUxMiJ9.....C_YhiOtjXyb_H0ybJlXEVSdtlqB-YRtbDQlrW2D1C_ZWOLc1OpS0plRbuWGIR5d3tdXnazwlpaLI7j7iR9tQWlU2tbU7LW-p_naoROkdlhPkMTC-f1k5eR98Km1x_UctkODqlAakNgg3uc352ylGIcY2HnLedFWhie5vtChAnQRfVHxRl2UMKryuJVWVzlKzAGS-SvXoFaxUa_luU58UchoOgdj6_j5tnm-tYk_rGlYFHdyg9zymPM4Okdi8LwD3izHoPeoDMrgh0qo4bBfS4E7H4oGjuLer6yhWTUiXz_GNhPU8Lc4W_5w40L2gv9PIQFOLDBzWMfIeVcMIUR9saA; is_login=1; bm_sv=5A81437DF5151EF433136FC9332E80A2~~1',
      'dnt': '1',
      'gid': 'LOCATION,INDUSTRY,EDUCATION,FAREA_ROLE',
      'referer': 'https://www.naukri.com/value-at-risk-jobs?k=value^%^20at^%^20risk&nignbevent_src=jobsearchDeskGNB',
      'sec-ch-ua': '^\\^Microsoft',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '^\\^Windows^\\^',
      'sec-fetch-dest': 'empty',
      'sec-fetch-mode': 'cors',
      'sec-fetch-site': 'same-origin',
      'systemid': 'Naukri',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36 Edg/119.0.0.0',
  }

  params = (
      ('noOfResults', '20'),
      ('urlType', 'search_by_keyword'),
      ('searchType', 'adv'),
      ('keyword', 'value^%^20at^%^20risk'),
      ('pageNo', str(j)),
      ('k', 'value^%^20at^%^20risk'),
      ('nignbevent_src', 'jobsearchDeskGNB'),
      ('seoKey', 'value-at-risk-jobs'),
      ('src', 'jobsearchDesk'),
      ('latLong', ''),
  )

  response = requests.get('https://www.naukri.com/jobapi/v3/search', headers=headers, params=params)

  main_file=response.json()['jobDetails']

  for i in main_file :
    #job description
    soup = BeautifulSoup(i['jobDescription'], 'html.parser').prettify()
    soup=soup.replace('<br/>','.')
    soup=soup.replace('\n','')
    soup=soup.replace('&amp;','&')
    description.append(soup)
    # job title
    job.append(i['title'] )
    # company
    company.append( i['companyName'] )
    # skillset
    # skills.append(i['tagsAndSkills'] )
    # salary
    salary.append( i['placeholders'][1]['label'] )
    # location
    location.append( i['placeholders'][2]['label'] )
    # experience
    experience.append( i['placeholders'][0]['label'] )
    # link for more details
    url.append( f"www.naukri.com{i['jdURL']}")
    #dataframe
    data=  pd.DataFrame({'title':job ,
                         'description':description ,
                         'company':company,
            ' salary ': salary, 'location':location,
            'experience': experience,'link':url,})

# %%
data
# Out:
#                                                  title  \
# 0                                  PHP MySQL Developer
# 1                                         Web Designer
# 2    Data Scientist (Generative AI) BIG4 Consultant...
# 3    S&C Global Network - AI - Marketing Analytics ...
# 4                                      Product analyst
# ..                                                 ...
# 995                Inside Sales Associate-Inside Sales
# 996     Hiring For " Process Champion- Defined Benefit
# 997                           Oracle Xstore Consultant
# 998  Hiring For Travel Consultant/Sr Travel Consult...
# 999  Procurement Practice New Associate - Procureme...
#
#                                            description  \
# 0    . MCA,BTech,Any Graduate..Good knowledge of HT...
# 1    . MCA,BTech,Any Graduate... Good knowledge in ...
# 2    Required Skills:  . LLM Applications : Experie...
# 3    Working through the phases of project oDefine ...
# ...

# %%
data.to_excel("jobs.xlsx")
